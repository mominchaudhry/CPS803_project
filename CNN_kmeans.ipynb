# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from sklearn.cluster import KMeans

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %%
trans = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
data = torchvision.datasets.ImageFolder(root='Images', transform=trans)
traindata, testvaldata = torch.utils.data.random_split(data, [12000, 8580])
valdata, testdata = torch.utils.data.random_split(testvaldata, [4000, 4580])

print(traindata, testdata)
# Out:
# <torch.utils.data.dataset.Subset object at 0x00000167A7D2F640> <torch.utils.data.dataset.Subset object at 0x00000167B4444160>

# %%
trainloader = torch.utils.data.DataLoader(traindata, batch_size=1, shuffle=True)
testloader = torch.utils.data.DataLoader(testdata, batch_size=1, shuffle=True)
print(trainloader, testloader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x00000167B4438DF0> <torch.utils.data.dataloader.DataLoader object at 0x00000167B4438DC0>

# %%
import torchvision.models as models
net = models.resnet50(pretrained=True)
num = net.fc.in_features
net.fc = nn.Linear(num, 120)

PATH = './resnet50.pth'
net.load_state_dict(torch.load(PATH))

layer = net._modules.get('avgpool')
net.eval()
net.to(device)
# num = net.fc.in_features
# net.fc = nn.Linear(num, 120)
# net.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=120, bias=True)
# )

# %%
"""   K MEANS   """

features = np.empty((0, 2048))
train_labels = np.zeros(0)
running_loss = 0.0
for i, data in enumerate(trainloader, 0):
    # get the inputs; data is a list of [inputs, labels]
    inputs, labels = data[0].to(device), data[1].to(device)
    my_embedding = torch.zeros(2048)
    def copy_data(m, i, o):
        my_embedding.copy_(o.data.reshape(o.data.size(1)))

    h = layer.register_forward_hook(copy_data)

    net(inputs)
    h.remove()

    features = np.append(features, my_embedding.reshape(1, len(my_embedding)), axis=0)
    train_labels = np.append(train_labels, labels.cpu().numpy(), axis=0)
print('Finished Training')
print(features.shape)
# Out:
# Finished Training
# (12000, 2048)

# %%
testfeatures = np.empty((0, 2048))
testlabels = np.zeros(0)
for i, data in enumerate(testloader, 0):
    # get the inputs; data is a list of [inputs, labels]
    inputs, labels = data[0].to(device), data[1].to(device)
    my_embedding = torch.zeros(2048)
    def copy_data(m, i, o):
        my_embedding.copy_(o.data.reshape(o.data.size(1)))

    h = layer.register_forward_hook(copy_data)
    
    net(inputs)
    h.remove()

    testfeatures = np.append(testfeatures, my_embedding.reshape(1, len(my_embedding)), axis=0)
    testlabels = np.append(testlabels, labels.cpu().numpy(), axis=0)
print(testfeatures.shape)
# Out:
# (4580, 2048)

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(features, train_labels)
preds = clf.predict(testfeatures)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(testlabels, preds)
np.savetxt('confusion.txt', cm)

from sklearn.metrics import accuracy_score
meanacc = accuracy_score(testlabels, preds)*100
classacc = 100*(cm.diagonal()/cm.sum(axis=1))
f = open("classes.txt", "r")
classmap = {}
for i in range(120):
    classs = f.readline().split(" ")
    classmap[classs[0]] = classacc[i]
    
sortedmap = sorted(classmap.items(), key=lambda item: item[1], reverse=True)

for k, v in sortedmap:
    print('Accuracy of %30s : %10d %%' % (k, v))
print('Mean accuracy: %5f %%' % meanacc)
# Out:
# Accuracy of                    Maltese_dog :        100 %
# Accuracy of               Blenheim_spaniel :        100 %
# Accuracy of                   Afghan_hound :        100 %
# Accuracy of                         Saluki :        100 %
# Accuracy of                     Weimaraner :        100 %
# Accuracy of                          cairn :        100 %
# Accuracy of                 Scotch_terrier :        100 %
# Accuracy of                         vizsla :        100 %
# Accuracy of                   Irish_setter :        100 %
# Accuracy of                        clumber :        100 %
# Accuracy of                 cocker_spaniel :        100 %
# Accuracy of                 Sussex_spaniel :        100 %
# Accuracy of           Old_English_sheepdog :        100 %
# Accuracy of             miniature_pinscher :        100 %
# Accuracy of                  Saint_Bernard :        100 %
# Accuracy of                        basenji :        100 %
# Accuracy of                        Samoyed :        100 %
# Accuracy of                       keeshond :        100 %
# Accuracy of               Mexican_hairless :        100 %
# Accuracy of             Norwegian_elkhound :         97 %
# Accuracy of                   Ibizan_hound :         97 %
# Accuracy of                           chow :         97 %
# Accuracy of                       komondor :         97 %
# Accuracy of                       Leonberg :         97 %
# Accuracy of                         basset :         97 %
# Accuracy of        black_and_tan_coonhound :         97 %
# Accuracy of                     Pomeranian :         97 %
# Accuracy of               English_springer :         97 %
# Accuracy of                     bloodhound :         97 %
# Accuracy of                 French_bulldog :         97 %
# Accuracy of            Rhodesian_ridgeback :         97 %
# Accuracy of             Bedlington_terrier :         97 %
# Accuracy of                            pug :         97 %
# Accuracy of                       bluetick :         97 %
# Accuracy of            Irish_water_spaniel :         97 %
# Accuracy of                     Rottweiler :         97 %
# Accuracy of                  affenpinscher :         97 %
# Accuracy of            African_hunting_dog :         97 %
# Accuracy of                         borzoi :         97 %
# Accuracy of       Chesapeake_Bay_retriever :         97 %
# Accuracy of                     schipperke :         97 %
# Accuracy of                 Border_terrier :         97 %
# Accuracy of    German_short_haired_pointer :         97 %
# Accuracy of                  Gordon_setter :         97 %
# Accuracy of                          dingo :         97 %
# Accuracy of                    Boston_bull :         96 %
# Accuracy of              Brabancon_griffon :         96 %
# Accuracy of                   Newfoundland :         96 %
# Accuracy of    soft_coated_wheaten_terrier :         96 %
# Accuracy of                   bull_mastiff :         96 %
# Accuracy of                          dhole :         96 %
# Accuracy of                    toy_terrier :         96 %
# Accuracy of           Bernese_mountain_dog :         96 %
# Accuracy of            miniature_schnauzer :         96 %
# Accuracy of                    EntleBucher :         95 %
# Accuracy of                giant_schnauzer :         95 %
# Accuracy of         Welsh_springer_spaniel :         95 %
# Accuracy of                       Pembroke :         95 %
# Accuracy of                        whippet :         95 %
# Accuracy of             Scottish_deerhound :         95 %
# Accuracy of                Tibetan_terrier :         95 %
# Accuracy of                       papillon :         95 %
# Accuracy of               Sealyham_terrier :         95 %
# Accuracy of               Japanese_spaniel :         95 %
# Accuracy of    West_Highland_white_terrier :         94 %
# Accuracy of         curly_coated_retriever :         94 %
# Accuracy of             Labrador_retriever :         94 %
# Accuracy of     Greater_Swiss_Mountain_dog :         94 %
# Accuracy of                       Airedale :         93 %
# Accuracy of               golden_retriever :         93 %
# Accuracy of                Tibetan_mastiff :         93 %
# Accuracy of                         beagle :         93 %
# Accuracy of              Italian_greyhound :         93 %
# Accuracy of                 English_setter :         93 %
# Accuracy of                    groenendael :         93 %
# Accuracy of                Norwich_terrier :         92 %
# Accuracy of                       malinois :         92 %
# Accuracy of              Shetland_sheepdog :         92 %
# Accuracy of                      Chihuahua :         92 %
# Accuracy of                 Great_Pyrenees :         92 %
# Accuracy of          flat_coated_retriever :         91 %
# Accuracy of                       Cardigan :         91 %
# Accuracy of                       Pekinese :         91 %
# Accuracy of             Kerry_blue_terrier :         91 %
# Accuracy of           Bouvier_des_Flandres :         91 %
# Accuracy of                Irish_wolfhound :         91 %
# Accuracy of                        redbone :         90 %
# Accuracy of                       Doberman :         90 %
# Accuracy of             standard_schnauzer :         90 %
# Accuracy of                          boxer :         90 %
# Accuracy of                         briard :         89 %
# Accuracy of                       Shih_Tzu :         89 %
# Accuracy of                  silky_terrier :         89 %
# Accuracy of                  Border_collie :         89 %
# Accuracy of                       malamute :         89 %
# Accuracy of               Brittany_spaniel :         89 %
# Accuracy of                         kelpie :         88 %
# Accuracy of                German_shepherd :         87 %
# Accuracy of                 Dandie_Dinmont :         87 %
# Accuracy of                     otterhound :         87 %
# Accuracy of                         collie :         87 %
# Accuracy of                standard_poodle :         87 %
# Accuracy of                  Irish_terrier :         86 %
# Accuracy of               English_foxhound :         86 %
# Accuracy of                          Lhasa :         86 %
# Accuracy of                   Walker_hound :         86 %
# Accuracy of              Yorkshire_terrier :         86 %
# Accuracy of      Staffordshire_bullterrier :         86 %
# Accuracy of                         kuvasz :         86 %
# Accuracy of                Norfolk_terrier :         85 %
# Accuracy of                 Siberian_husky :         85 %
# Accuracy of             Australian_terrier :         84 %
# Accuracy of                    Appenzeller :         84 %
# Accuracy of               miniature_poodle :         83 %
# Accuracy of        wire_haired_fox_terrier :         81 %
# Accuracy of                     Eskimo_dog :         80 %
# Accuracy of               Lakeland_terrier :         79 %
# Accuracy of                     Great_Dane :         78 %
# Accuracy of                     toy_poodle :         75 %
# Accuracy of American_Staffordshire_terrier :         74 %
# Mean accuracy: 93.624454 %

# %%
kmeans = KMeans(n_clusters=120)
kmeans.fit(features)
trainl = kmeans.labels_

testl = kmeans.predict(testfeatures)

# %%
from sklearn import svm
s = svm.SVC()
s.fit(features, trainl)
preds = s.predict(testfeatures)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(preds, testlabels)
np.savetxt('confusion.txt', cm)
m = np.zeros(120)
max = 0
for i in range(len(cm)):
    max = 0
    for j in range(len(cm.T)):
        curr = cm[i][j]
        if curr > max:
            max = curr
            m[i] = j
newpreds = np.zeros(len(preds))
for i in range(len(preds)):
    newpreds[i] = m[preds[i]]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(testlabels, newpreds)
np.savetxt('confusion.txt', cm)

meanacc = accuracy_score(testlabels, newpreds)*100
classacc = 100*(cm.diagonal()/(cm.sum(axis=1)))
f = open("classes.txt", "r")
classmap = {}
for i in range(120):
    classs = f.readline().split(" ")
    classmap[classs[0]] = classacc[i]
    
sortedmap = sorted(classmap.items(), key=lambda item: item[1], reverse=True)

for k, v in sortedmap:
    print('Accuracy of %30s : %10d %%' % (k, v))
print('Mean accuracy: %5f %%' % meanacc)
# Out:
# Accuracy of                         basset :        100 %
# Accuracy of                         borzoi :        100 %
# Accuracy of             Bedlington_terrier :        100 %
# Accuracy of               Sealyham_terrier :        100 %
# Accuracy of          flat_coated_retriever :        100 %
# Accuracy of             Labrador_retriever :        100 %
# Accuracy of                        clumber :        100 %
# Accuracy of               English_springer :        100 %
# Accuracy of         Welsh_springer_spaniel :        100 %
# Accuracy of                       komondor :        100 %
# Accuracy of                     Rottweiler :        100 %
# Accuracy of                     Great_Dane :        100 %
# Accuracy of                  Saint_Bernard :        100 %
# Accuracy of                  affenpinscher :        100 %
# Accuracy of                       Leonberg :        100 %
# Accuracy of                           chow :        100 %
# Accuracy of            African_hunting_dog :        100 %
# Accuracy of                   Afghan_hound :         98 %
# Accuracy of             Scottish_deerhound :         98 %
# Accuracy of                Tibetan_terrier :         98 %
# Accuracy of               Blenheim_spaniel :         97 %
# Accuracy of    West_Highland_white_terrier :         97 %
# Accuracy of           Bernese_mountain_dog :         97 %
# Accuracy of                       Pembroke :         97 %
# Accuracy of             Kerry_blue_terrier :         97 %
# Accuracy of                          boxer :         97 %
# Accuracy of               Japanese_spaniel :         97 %
# Accuracy of                    Boston_bull :         97 %
# Accuracy of             Norwegian_elkhound :         97 %
# Accuracy of                     schipperke :         97 %
# Accuracy of                 Siberian_husky :         97 %
# Accuracy of                     bloodhound :         97 %
# Accuracy of                     Weimaraner :         97 %
# Accuracy of American_Staffordshire_terrier :         97 %
# Accuracy of           Bouvier_des_Flandres :         97 %
# Accuracy of                 French_bulldog :         97 %
# Accuracy of               Mexican_hairless :         97 %
# Accuracy of                  Gordon_setter :         97 %
# Accuracy of                    EntleBucher :         97 %
# Accuracy of                   Newfoundland :         97 %
# Accuracy of                     toy_poodle :         97 %
# Accuracy of            Irish_water_spaniel :         97 %
# Accuracy of                 Sussex_spaniel :         96 %
# Accuracy of           Old_English_sheepdog :         96 %
# Accuracy of                       keeshond :         96 %
# Accuracy of              Brabancon_griffon :         96 %
# Accuracy of                          dhole :         96 %
# Accuracy of                    Maltese_dog :         96 %
# Accuracy of    soft_coated_wheaten_terrier :         96 %
# Accuracy of                 Scotch_terrier :         96 %
# Accuracy of                   Irish_setter :         96 %
# Accuracy of                     Pomeranian :         96 %
# Accuracy of                       papillon :         96 %
# Accuracy of                            pug :         95 %
# Accuracy of             miniature_pinscher :         95 %
# Accuracy of                  Irish_terrier :         95 %
# Accuracy of             standard_schnauzer :         95 %
# Accuracy of                   bull_mastiff :         95 %
# Accuracy of                          cairn :         94 %
# Accuracy of                 Dandie_Dinmont :         94 %
# Accuracy of                giant_schnauzer :         94 %
# Accuracy of                 English_setter :         94 %
# Accuracy of                 Border_terrier :         94 %
# Accuracy of                        basenji :         94 %
# Accuracy of       Chesapeake_Bay_retriever :         94 %
# Accuracy of     Greater_Swiss_Mountain_dog :         94 %
# Accuracy of                         beagle :         93 %
# Accuracy of                       Airedale :         93 %
# Accuracy of              Shetland_sheepdog :         93 %
# Accuracy of                        Samoyed :         93 %
# Accuracy of                   Walker_hound :         92 %
# Accuracy of                   Ibizan_hound :         92 %
# Accuracy of                Norwich_terrier :         92 %
# Accuracy of         curly_coated_retriever :         92 %
# Accuracy of                      Chihuahua :         92 %
# Accuracy of                       Pekinese :         92 %
# Accuracy of                Irish_wolfhound :         92 %
# Accuracy of                         briard :         92 %
# Accuracy of                        whippet :         92 %
# Accuracy of                standard_poodle :         92 %
# Accuracy of                    groenendael :         92 %
# Accuracy of                         Saluki :         91 %
# Accuracy of                 cocker_spaniel :         91 %
# Accuracy of                 Great_Pyrenees :         91 %
# Accuracy of              Yorkshire_terrier :         90 %
# Accuracy of               golden_retriever :         90 %
# Accuracy of                          dingo :         90 %
# Accuracy of                         kelpie :         90 %
# Accuracy of                        redbone :         90 %
# Accuracy of               Lakeland_terrier :         90 %
# Accuracy of             Australian_terrier :         89 %
# Accuracy of                         kuvasz :         89 %
# Accuracy of        black_and_tan_coonhound :         89 %
# Accuracy of                     otterhound :         89 %
# Accuracy of                  Border_collie :         89 %
# Accuracy of              Italian_greyhound :         89 %
# Accuracy of                Tibetan_mastiff :         88 %
# Accuracy of                         vizsla :         88 %
# Accuracy of                       malinois :         87 %
# Accuracy of               Brittany_spaniel :         87 %
# Accuracy of                       malamute :         87 %
# Accuracy of    German_short_haired_pointer :         87 %
# Accuracy of        wire_haired_fox_terrier :         86 %
# Accuracy of                       bluetick :         83 %
# Accuracy of                       Doberman :         83 %
# Accuracy of                  silky_terrier :         82 %
# Accuracy of                          Lhasa :         80 %
# Accuracy of                German_shepherd :         80 %
# Accuracy of                       Cardigan :         80 %
# Accuracy of                    toy_terrier :         78 %
# Accuracy of                       Shih_Tzu :         75 %
# Accuracy of                    Appenzeller :         73 %
# Accuracy of               English_foxhound :         61 %
# Accuracy of                         collie :         35 %
# Accuracy of            Rhodesian_ridgeback :          0 %
# Accuracy of      Staffordshire_bullterrier :          0 %
# Accuracy of                Norfolk_terrier :          0 %
# Accuracy of            miniature_schnauzer :          0 %
# Accuracy of                     Eskimo_dog :          0 %
# Accuracy of               miniature_poodle :          0 %
# Mean accuracy: 89.148472 %
