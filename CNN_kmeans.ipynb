# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from sklearn.cluster import KMeans

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %%
trans = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
data = torchvision.datasets.ImageFolder(root='Images', transform=trans)
traindata, testdata = torch.utils.data.random_split(data, [12000, 8580])
print(traindata, testdata)
# Out:
# <torch.utils.data.dataset.Subset object at 0x0000023A158794C0> <torch.utils.data.dataset.Subset object at 0x0000023A15879CA0>

# %%
trainloader = torch.utils.data.DataLoader(traindata, batch_size=1, shuffle=True)
testloader = torch.utils.data.DataLoader(testdata, batch_size=1, shuffle=True)
print(trainloader, testloader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x0000023A2462F970> <torch.utils.data.dataloader.DataLoader object at 0x0000023A2462FA30>

# %%
import torchvision.models as models
net = models.resnet50(pretrained=True)

layer = net._modules.get('avgpool')
net.eval()
net.to(device)
# num = net.fc.in_features
# net.fc = nn.Linear(num, 120)
# net.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
"""   K MEANS   """

features = np.empty((0, 2048))
train_labels = np.zeros(0)
running_loss = 0.0
for i, data in enumerate(trainloader, 0):
    # get the inputs; data is a list of [inputs, labels]
    inputs, labels = data[0].to(device), data[1].to(device)
    my_embedding = torch.zeros(2048)
    def copy_data(m, i, o):
        my_embedding.copy_(o.data.reshape(o.data.size(1)))

    h = layer.register_forward_hook(copy_data)

    net(inputs)
    h.remove()

    features = np.append(features, my_embedding.reshape(1, len(my_embedding)), axis=0)
    train_labels = np.append(train_labels, labels.cpu().numpy(), axis=0)
print('Finished Training')
print(features.shape)
# Out:
# Finished Training
# (12000, 2048)

# %%
testfeatures = np.empty((0, 2048))
testlabels = np.zeros(0)
for i, data in enumerate(testloader, 0):
    # get the inputs; data is a list of [inputs, labels]
    inputs, labels = data[0].to(device), data[1].to(device)
    my_embedding = torch.zeros(2048)
    def copy_data(m, i, o):
        my_embedding.copy_(o.data.reshape(o.data.size(1)))

    h = layer.register_forward_hook(copy_data)
    
    net(inputs)
    h.remove()

    testfeatures = np.append(testfeatures, my_embedding.reshape(1, len(my_embedding)), axis=0)
    testlabels = np.append(testlabels, labels.cpu().numpy(), axis=0)
print(testfeatures.shape)
# Out:
# (8580, 2048)

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(features, train_labels)
preds = clf.predict(testfeatures)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(testlabels, preds)
np.savetxt('confusion.txt', cm)

from sklearn.metrics import accuracy_score
meanacc = accuracy_score(testlabels, preds)*100
classacc = 100*(cm.diagonal()/cm.sum(axis=1))
f = open("classes.txt", "r")
classmap = {}
for i in range(120):
    classs = f.readline().split(" ")
    classmap[classs[0]] = classacc[i]
    
sortedmap = sorted(classmap.items(), key=lambda item: item[1], reverse=True)

for k, v in sortedmap:
    print('Accuracy of %30s : %10d %%' % (k, v))
print('Mean accuracy: %5f %%' % meanacc)
# Out:
# Accuracy of                        Samoyed :         99 %
# Accuracy of                       keeshond :         98 %
# Accuracy of           Bernese_mountain_dog :         97 %
# Accuracy of                            pug :         97 %
# Accuracy of                  Saint_Bernard :         97 %
# Accuracy of    West_Highland_white_terrier :         97 %
# Accuracy of               Sealyham_terrier :         96 %
# Accuracy of             Bedlington_terrier :         96 %
# Accuracy of                       Leonberg :         94 %
# Accuracy of                 Border_terrier :         93 %
# Accuracy of                   Afghan_hound :         93 %
# Accuracy of                           chow :         93 %
# Accuracy of                    Boston_bull :         93 %
# Accuracy of            African_hunting_dog :         93 %
# Accuracy of         curly_coated_retriever :         92 %
# Accuracy of                  Border_collie :         92 %
# Accuracy of                   bull_mastiff :         92 %
# Accuracy of           Old_English_sheepdog :         92 %
# Accuracy of                        clumber :         92 %
# Accuracy of                    Maltese_dog :         92 %
# Accuracy of                       komondor :         91 %
# Accuracy of               Blenheim_spaniel :         91 %
# Accuracy of                          dhole :         91 %
# Accuracy of             Norwegian_elkhound :         91 %
# Accuracy of                    groenendael :         91 %
# Accuracy of                     Pomeranian :         90 %
# Accuracy of              Brabancon_griffon :         89 %
# Accuracy of                 Scotch_terrier :         89 %
# Accuracy of                     schipperke :         89 %
# Accuracy of             Kerry_blue_terrier :         89 %
# Accuracy of               Japanese_spaniel :         89 %
# Accuracy of                         Saluki :         89 %
# Accuracy of               English_springer :         88 %
# Accuracy of                 French_bulldog :         88 %
# Accuracy of                  affenpinscher :         88 %
# Accuracy of                         basset :         88 %
# Accuracy of           Bouvier_des_Flandres :         88 %
# Accuracy of               Mexican_hairless :         87 %
# Accuracy of                         borzoi :         87 %
# Accuracy of                   Newfoundland :         87 %
# Accuracy of                       papillon :         86 %
# Accuracy of                   Irish_setter :         86 %
# Accuracy of            Irish_water_spaniel :         86 %
# Accuracy of                 Dandie_Dinmont :         85 %
# Accuracy of                 Great_Pyrenees :         85 %
# Accuracy of                 Sussex_spaniel :         85 %
# Accuracy of                  Gordon_setter :         85 %
# Accuracy of                          dingo :         85 %
# Accuracy of          flat_coated_retriever :         84 %
# Accuracy of                       Pembroke :         83 %
# Accuracy of                        basenji :         83 %
# Accuracy of                     bloodhound :         83 %
# Accuracy of                giant_schnauzer :         83 %
# Accuracy of             Scottish_deerhound :         83 %
# Accuracy of        black_and_tan_coonhound :         82 %
# Accuracy of             miniature_pinscher :         82 %
# Accuracy of                     Rottweiler :         82 %
# Accuracy of                     Weimaraner :         82 %
# Accuracy of                       Pekinese :         81 %
# Accuracy of             Labrador_retriever :         81 %
# Accuracy of                       bluetick :         80 %
# Accuracy of                     otterhound :         80 %
# Accuracy of               golden_retriever :         79 %
# Accuracy of                          boxer :         79 %
# Accuracy of       Chesapeake_Bay_retriever :         79 %
# Accuracy of                         briard :         79 %
# Accuracy of                Irish_wolfhound :         79 %
# Accuracy of                Tibetan_terrier :         79 %
# Accuracy of     Greater_Swiss_Mountain_dog :         78 %
# Accuracy of                       Doberman :         78 %
# Accuracy of    German_short_haired_pointer :         77 %
# Accuracy of                        whippet :         77 %
# Accuracy of                   Ibizan_hound :         77 %
# Accuracy of                         kuvasz :         77 %
# Accuracy of                    EntleBucher :         76 %
# Accuracy of                Norwich_terrier :         76 %
# Accuracy of              Italian_greyhound :         76 %
# Accuracy of                    toy_terrier :         75 %
# Accuracy of                      Chihuahua :         75 %
# Accuracy of                         beagle :         75 %
# Accuracy of              Yorkshire_terrier :         75 %
# Accuracy of                       malamute :         75 %
# Accuracy of                       Airedale :         74 %
# Accuracy of                 English_setter :         74 %
# Accuracy of                       malinois :         74 %
# Accuracy of            miniature_schnauzer :         73 %
# Accuracy of                 cocker_spaniel :         73 %
# Accuracy of American_Staffordshire_terrier :         72 %
# Accuracy of                       Shih_Tzu :         72 %
# Accuracy of    soft_coated_wheaten_terrier :         72 %
# Accuracy of                standard_poodle :         72 %
# Accuracy of            Rhodesian_ridgeback :         71 %
# Accuracy of                German_shepherd :         71 %
# Accuracy of               Brittany_spaniel :         71 %
# Accuracy of                Tibetan_mastiff :         71 %
# Accuracy of                       Cardigan :         71 %
# Accuracy of                          cairn :         70 %
# Accuracy of                         kelpie :         70 %
# Accuracy of                        redbone :         68 %
# Accuracy of         Welsh_springer_spaniel :         68 %
# Accuracy of                  Irish_terrier :         65 %
# Accuracy of        wire_haired_fox_terrier :         65 %
# Accuracy of                Norfolk_terrier :         64 %
# Accuracy of                     Great_Dane :         64 %
# Accuracy of      Staffordshire_bullterrier :         63 %
# Accuracy of             Australian_terrier :         63 %
# Accuracy of                     toy_poodle :         63 %
# Accuracy of                   Walker_hound :         63 %
# Accuracy of               Lakeland_terrier :         61 %
# Accuracy of              Shetland_sheepdog :         60 %
# Accuracy of             standard_schnauzer :         60 %
# Accuracy of               miniature_poodle :         60 %
# Accuracy of                         vizsla :         59 %
# Accuracy of                 Siberian_husky :         58 %
# Accuracy of                          Lhasa :         56 %
# Accuracy of                  silky_terrier :         55 %
# Accuracy of                    Appenzeller :         52 %
# Accuracy of               English_foxhound :         51 %
# Accuracy of                         collie :         42 %
# Accuracy of                     Eskimo_dog :         37 %
# Mean accuracy: 79.836830 %

# %%
kmeans = KMeans(n_clusters=120)
kmeans.fit(features)
preds = kmeans.predict(testfeatures)
print(testlabels.shape)
# Out:
# (8580,)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(testlabels, preds)
np.savetxt('confusion.txt', cm)

meanacc = accuracy_score(testlabels, preds)*100
classacc = 100*(cm.diagonal()/(cm.sum(axis=1)+0.01))
f = open("classes.txt", "r")
classmap = {}
for i in range(120):
    classs = f.readline().split(" ")
    classmap[classs[0]] = classacc[i]
    
sortedmap = sorted(classmap.items(), key=lambda item: item[1], reverse=True)

for k, v in sortedmap:
    print('Accuracy of %30s : %10d %%' % (k, v))
print('Mean accuracy: %5f %%' % meanacc)
# Out:
# Accuracy of                  affenpinscher :         49 %
# Accuracy of                       Shih_Tzu :          8 %
# Accuracy of               golden_retriever :          7 %
# Accuracy of                     schipperke :          3 %
# Accuracy of                   Irish_setter :          3 %
# Accuracy of      Staffordshire_bullterrier :          1 %
# Accuracy of                     bloodhound :          1 %
# Accuracy of                      Chihuahua :          0 %
# Accuracy of               Japanese_spaniel :          0 %
# Accuracy of                    Maltese_dog :          0 %
# Accuracy of                       Pekinese :          0 %
# Accuracy of               Blenheim_spaniel :          0 %
# Accuracy of                       papillon :          0 %
# Accuracy of                    toy_terrier :          0 %
# Accuracy of            Rhodesian_ridgeback :          0 %
# Accuracy of                   Afghan_hound :          0 %
# Accuracy of                         basset :          0 %
# Accuracy of                         beagle :          0 %
# Accuracy of                       bluetick :          0 %
# Accuracy of        black_and_tan_coonhound :          0 %
# Accuracy of                   Walker_hound :          0 %
# Accuracy of               English_foxhound :          0 %
# Accuracy of                        redbone :          0 %
# Accuracy of                         borzoi :          0 %
# Accuracy of                Irish_wolfhound :          0 %
# Accuracy of              Italian_greyhound :          0 %
# Accuracy of                        whippet :          0 %
# Accuracy of                   Ibizan_hound :          0 %
# Accuracy of             Norwegian_elkhound :          0 %
# Accuracy of                     otterhound :          0 %
# Accuracy of                         Saluki :          0 %
# Accuracy of             Scottish_deerhound :          0 %
# Accuracy of                     Weimaraner :          0 %
# Accuracy of American_Staffordshire_terrier :          0 %
# Accuracy of             Bedlington_terrier :          0 %
# Accuracy of                 Border_terrier :          0 %
# Accuracy of             Kerry_blue_terrier :          0 %
# Accuracy of                  Irish_terrier :          0 %
# Accuracy of                Norfolk_terrier :          0 %
# Accuracy of                Norwich_terrier :          0 %
# Accuracy of              Yorkshire_terrier :          0 %
# Accuracy of        wire_haired_fox_terrier :          0 %
# Accuracy of               Lakeland_terrier :          0 %
# Accuracy of               Sealyham_terrier :          0 %
# Accuracy of                       Airedale :          0 %
# Accuracy of                          cairn :          0 %
# Accuracy of             Australian_terrier :          0 %
# Accuracy of                 Dandie_Dinmont :          0 %
# Accuracy of                    Boston_bull :          0 %
# Accuracy of            miniature_schnauzer :          0 %
# Accuracy of                giant_schnauzer :          0 %
# Accuracy of             standard_schnauzer :          0 %
# Accuracy of                 Scotch_terrier :          0 %
# Accuracy of                Tibetan_terrier :          0 %
# Accuracy of                  silky_terrier :          0 %
# Accuracy of    soft_coated_wheaten_terrier :          0 %
# Accuracy of    West_Highland_white_terrier :          0 %
# Accuracy of                          Lhasa :          0 %
# Accuracy of          flat_coated_retriever :          0 %
# Accuracy of         curly_coated_retriever :          0 %
# Accuracy of             Labrador_retriever :          0 %
# Accuracy of       Chesapeake_Bay_retriever :          0 %
# Accuracy of    German_short_haired_pointer :          0 %
# Accuracy of                         vizsla :          0 %
# Accuracy of                 English_setter :          0 %
# Accuracy of                  Gordon_setter :          0 %
# Accuracy of               Brittany_spaniel :          0 %
# Accuracy of                        clumber :          0 %
# Accuracy of               English_springer :          0 %
# Accuracy of         Welsh_springer_spaniel :          0 %
# Accuracy of                 cocker_spaniel :          0 %
# Accuracy of                 Sussex_spaniel :          0 %
# Accuracy of            Irish_water_spaniel :          0 %
# Accuracy of                         kuvasz :          0 %
# Accuracy of                    groenendael :          0 %
# Accuracy of                       malinois :          0 %
# Accuracy of                         briard :          0 %
# Accuracy of                         kelpie :          0 %
# Accuracy of                       komondor :          0 %
# Accuracy of           Old_English_sheepdog :          0 %
# Accuracy of              Shetland_sheepdog :          0 %
# Accuracy of                         collie :          0 %
# Accuracy of                  Border_collie :          0 %
# Accuracy of           Bouvier_des_Flandres :          0 %
# Accuracy of                     Rottweiler :          0 %
# Accuracy of                German_shepherd :          0 %
# Accuracy of                       Doberman :          0 %
# Accuracy of             miniature_pinscher :          0 %
# Accuracy of     Greater_Swiss_Mountain_dog :          0 %
# Accuracy of           Bernese_mountain_dog :          0 %
# Accuracy of                    Appenzeller :          0 %
# Accuracy of                    EntleBucher :          0 %
# Accuracy of                          boxer :          0 %
# Accuracy of                   bull_mastiff :          0 %
# Accuracy of                Tibetan_mastiff :          0 %
# Accuracy of                 French_bulldog :          0 %
# Accuracy of                     Great_Dane :          0 %
# Accuracy of                  Saint_Bernard :          0 %
# Accuracy of                     Eskimo_dog :          0 %
# Accuracy of                       malamute :          0 %
# Accuracy of                 Siberian_husky :          0 %
# Accuracy of                        basenji :          0 %
# Accuracy of                            pug :          0 %
# Accuracy of                       Leonberg :          0 %
# Accuracy of                   Newfoundland :          0 %
# Accuracy of                 Great_Pyrenees :          0 %
# Accuracy of                        Samoyed :          0 %
# Accuracy of                     Pomeranian :          0 %
# Accuracy of                           chow :          0 %
# Accuracy of                       keeshond :          0 %
# Accuracy of              Brabancon_griffon :          0 %
# Accuracy of                       Pembroke :          0 %
# Accuracy of                       Cardigan :          0 %
# Accuracy of                     toy_poodle :          0 %
# Accuracy of               miniature_poodle :          0 %
# Accuracy of                standard_poodle :          0 %
# Accuracy of               Mexican_hairless :          0 %
# Accuracy of                          dingo :          0 %
# Accuracy of                          dhole :          0 %
# Accuracy of            African_hunting_dog :          0 %
# Mean accuracy: 0.524476 %
