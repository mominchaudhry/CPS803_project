# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %%
trans = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # randomly flip and rotate
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])
data = torchvision.datasets.ImageFolder(root='Images', transform=trans)
traindata, testdata = torch.utils.data.random_split(data, [12000, 8580])
print(traindata, testdata)
# Out:
# <torch.utils.data.dataset.Subset object at 0x0000012A57099F40> <torch.utils.data.dataset.Subset object at 0x0000012A570A48E0>

# %%
trainloader = torch.utils.data.DataLoader(traindata, batch_size=4, shuffle=True)
testloader = torch.utils.data.DataLoader(testdata, batch_size = 4, shuffle=True)
print(trainloader, testloader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x0000012A051CDC40> <torch.utils.data.dataloader.DataLoader object at 0x0000012A56FDF160>

# %%
import torchvision.models as models
net = models.resnet18(pretrained=True)
num = net.fc.in_features
net.fc = nn.Linear(num, 120)
net.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=120, bias=True)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
for epoch in range(20):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device), data[1].to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 1000 == 999:    # print every 1000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0

print('Finished Training')
# Out:
# [1,  1000] loss: 1.878
# [1,  2000] loss: 1.324
# [1,  3000] loss: 1.141
# [2,  1000] loss: 1.001
# [2,  2000] loss: 0.954
# [2,  3000] loss: 0.905
# [3,  1000] loss: 0.804
# [3,  2000] loss: 0.797
# [3,  3000] loss: 0.790
# [4,  1000] loss: 0.666
# [4,  2000] loss: 0.708
# [4,  3000] loss: 0.702
# [5,  1000] loss: 0.595
# [5,  2000] loss: 0.594
# [5,  3000] loss: 0.630
# [6,  1000] loss: 0.503
# [6,  2000] loss: 0.561
# [6,  3000] loss: 0.543
# [7,  1000] loss: 0.472
# [7,  2000] loss: 0.473
# [7,  3000] loss: 0.509
# [8,  1000] loss: 0.414
# [8,  2000] loss: 0.423
# [8,  3000] loss: 0.450
# [9,  1000] loss: 0.354
# [9,  2000] loss: 0.389
# [9,  3000] loss: 0.413
# [10,  1000] loss: 0.324
# [10,  2000] loss: 0.357
# [10,  3000] loss: 0.367
# [11,  1000] loss: 0.284
# [11,  2000] loss: 0.317
# [11,  3000] loss: 0.335
# [12,  1000] loss: 0.276
# [12,  2000] loss: 0.284
# [12,  3000] loss: 0.316
# [13,  1000] loss: 0.230
# [13,  2000] loss: 0.249
# [13,  3000] loss: 0.245
# [14,  1000] loss: 0.204
# [14,  2000] loss: 0.221
# [14,  3000] loss: 0.234
# [15,  1000] loss: 0.194
# [15,  2000] loss: 0.215
# [15,  3000] loss: 0.209
# [16,  1000] loss: 0.181
# [16,  2000] loss: 0.189
# [16,  3000] loss: 0.220
# [17,  1000] loss: 0.160
# [17,  2000] loss: 0.160
# [17,  3000] loss: 0.176
# [18,  1000] loss: 0.142
# [18,  2000] loss: 0.143
# [18,  3000] loss: 0.174
# [19,  1000] loss: 0.131
# [19,  2000] loss: 0.132
# [19,  3000] loss: 0.158
# [20,  1000] loss: 0.117
# [20,  2000] loss: 0.126
# [20,  3000] loss: 0.136
# Finished Training

# %%
PATH = './resnet.pth'
torch.save(net.state_dict(), PATH)

# %%
net = Net()
net.to(device)
PATH = './model2.pth'
net.load_state_dict(torch.load(PATH))

# %%
correct = 0.0
total = 0.0
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
meanacc1 = (100 * correct / total)
print('Accuracy of the network on the 8580 test images: %.3f %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 8580 test images: 62.587 %

# %%
f = open("classes.txt", "r")
classmap = {}
for i in range(120):
    classs = f.readline().split(" ")
    classmap[i] = classs[0]

# %%
class_correct = list(0. for i in range(120))
class_total = list(0. for i in range(120))
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

newmap = {}
for i in range(120):
    newmap[classmap[i]] = 100 * class_correct[i] / class_total[i]
        
sortedmap = sorted(newmap.items(), key=lambda item: item[1], reverse=True)
for k, v in sortedmap:
    print('Accuracy of %30s : %10d %%' % (k, v))
print('Mean accuracy: %5f %%' % meanacc1)
# Out:
# Accuracy of                       Leonberg :         90 %
# Accuracy of             Bedlington_terrier :         89 %
# Accuracy of                       keeshond :         88 %
# Accuracy of                   Afghan_hound :         87 %
# Accuracy of                       Pembroke :         87 %
# Accuracy of             Kerry_blue_terrier :         85 %
# Accuracy of                 Scotch_terrier :         85 %
# Accuracy of               Sealyham_terrier :         84 %
# Accuracy of                 Sussex_spaniel :         83 %
# Accuracy of                        Samoyed :         83 %
# Accuracy of               Blenheim_spaniel :         81 %
# Accuracy of                       papillon :         81 %
# Accuracy of                  Saint_Bernard :         80 %
# Accuracy of            African_hunting_dog :         80 %
# Accuracy of                    groenendael :         79 %
# Accuracy of                     Pomeranian :         78 %
# Accuracy of                 French_bulldog :         78 %
# Accuracy of                 Dandie_Dinmont :         78 %
# Accuracy of                   bull_mastiff :         77 %
# Accuracy of           Bernese_mountain_dog :         77 %
# Accuracy of               Japanese_spaniel :         76 %
# Accuracy of                     otterhound :         76 %
# Accuracy of             Norwegian_elkhound :         75 %
# Accuracy of               English_springer :         75 %
# Accuracy of                Tibetan_mastiff :         75 %
# Accuracy of                  affenpinscher :         75 %
# Accuracy of                        basenji :         74 %
# Accuracy of                       komondor :         74 %
# Accuracy of                          dhole :         74 %
# Accuracy of               Mexican_hairless :         74 %
# Accuracy of                   Irish_setter :         74 %
# Accuracy of              Brabancon_griffon :         73 %
# Accuracy of    German_short_haired_pointer :         72 %
# Accuracy of                  Gordon_setter :         72 %
# Accuracy of                         kelpie :         72 %
# Accuracy of        black_and_tan_coonhound :         71 %
# Accuracy of                    Maltese_dog :         70 %
# Accuracy of                        redbone :         70 %
# Accuracy of                   Ibizan_hound :         70 %
# Accuracy of                        clumber :         70 %
# Accuracy of    West_Highland_white_terrier :         70 %
# Accuracy of                     schipperke :         70 %
# Accuracy of            Irish_water_spaniel :         70 %
# Accuracy of                     Weimaraner :         69 %
# Accuracy of                  Irish_terrier :         68 %
# Accuracy of                 Border_terrier :         68 %
# Accuracy of                         vizsla :         68 %
# Accuracy of                    EntleBucher :         67 %
# Accuracy of                          dingo :         67 %
# Accuracy of             miniature_pinscher :         67 %
# Accuracy of           Old_English_sheepdog :         66 %
# Accuracy of                Norwich_terrier :         65 %
# Accuracy of                          cairn :         65 %
# Accuracy of          flat_coated_retriever :         65 %
# Accuracy of                           chow :         65 %
# Accuracy of                         Saluki :         64 %
# Accuracy of                     Rottweiler :         64 %
# Accuracy of     Greater_Swiss_Mountain_dog :         64 %
# Accuracy of             Scottish_deerhound :         64 %
# Accuracy of              Yorkshire_terrier :         64 %
# Accuracy of         Welsh_springer_spaniel :         63 %
# Accuracy of               miniature_poodle :         63 %
# Accuracy of                         kuvasz :         63 %
# Accuracy of                Irish_wolfhound :         62 %
# Accuracy of                       Pekinese :         62 %
# Accuracy of                       bluetick :         61 %
# Accuracy of                     bloodhound :         61 %
# Accuracy of    soft_coated_wheaten_terrier :         61 %
# Accuracy of                   Newfoundland :         61 %
# Accuracy of                       malinois :         61 %
# Accuracy of       Chesapeake_Bay_retriever :         60 %
# Accuracy of               Brittany_spaniel :         59 %
# Accuracy of                         basset :         59 %
# Accuracy of                  Border_collie :         57 %
# Accuracy of                       Doberman :         57 %
# Accuracy of              Italian_greyhound :         55 %
# Accuracy of             standard_schnauzer :         55 %
# Accuracy of                          Lhasa :         55 %
# Accuracy of                          boxer :         54 %
# Accuracy of              Shetland_sheepdog :         54 %
# Accuracy of                       Airedale :         53 %
# Accuracy of                Tibetan_terrier :         53 %
# Accuracy of                      Chihuahua :         53 %
# Accuracy of                         beagle :         53 %
# Accuracy of                 Siberian_husky :         52 %
# Accuracy of           Bouvier_des_Flandres :         52 %
# Accuracy of                         collie :         51 %
# Accuracy of        wire_haired_fox_terrier :         50 %
# Accuracy of               golden_retriever :         50 %
# Accuracy of                    toy_terrier :         50 %
# Accuracy of                Norfolk_terrier :         50 %
# Accuracy of      Staffordshire_bullterrier :         50 %
# Accuracy of             Labrador_retriever :         50 %
# Accuracy of                         briard :         50 %
# Accuracy of                 Great_Pyrenees :         48 %
# Accuracy of                 English_setter :         48 %
# Accuracy of                    Boston_bull :         48 %
# Accuracy of                            pug :         47 %
# Accuracy of               Lakeland_terrier :         46 %
# Accuracy of                        whippet :         46 %
# Accuracy of         curly_coated_retriever :         46 %
# Accuracy of            miniature_schnauzer :         45 %
# Accuracy of                  silky_terrier :         44 %
# Accuracy of                         borzoi :         44 %
# Accuracy of             Australian_terrier :         42 %
# Accuracy of                       malamute :         41 %
# Accuracy of                   Walker_hound :         40 %
# Accuracy of                German_shepherd :         40 %
# Accuracy of                     Eskimo_dog :         39 %
# Accuracy of            Rhodesian_ridgeback :         38 %
# Accuracy of               English_foxhound :         38 %
# Accuracy of                    Appenzeller :         37 %
# Accuracy of                       Shih_Tzu :         37 %
# Accuracy of                 cocker_spaniel :         36 %
# Accuracy of                     Great_Dane :         36 %
# Accuracy of                giant_schnauzer :         35 %
# Accuracy of                standard_poodle :         35 %
# Accuracy of American_Staffordshire_terrier :         33 %
# Accuracy of                       Cardigan :         31 %
# Accuracy of                     toy_poodle :         18 %
# Mean accuracy: 62.587413 %

# %%
'''
BELOW are other CNNs, PERFORMS POORLY compared to resnet transfer
'''

# %%
'''
THIS IS PYTORCH TUTORIAL NET (NOT GOOD FOR FINE GRAIN)
'''

# import torch.nn as nn
# import torch.nn.functional as F


# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(3, 60, 5)
#         self.pool = nn.MaxPool2d(2, 2)
#         self.conv2 = nn.Conv2d(60, 16, 5)
#         self.fc1 = nn.Linear(16 * 53*53, 1000)
#         self.fc2 = nn.Linear(1000, 120)
# #         self.fc3 = nn.Linear(84, 10)

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))
#         x = self.pool(F.relu(self.conv2(x)))
#         x = x.view(x.size(0), 16*53*53)
#         x = F.relu(self.fc1(x))
#         #x = F.relu(self.fc2(x))
#         x = self.fc2(x)
#         return x


# net = Net()
# net.to(device)

# %%
'''
THIS IS BETTER NETWORK FOUND ON MEDIUM POST FOR FINE GRAINED CLASSIFICATION:
https://medium.com/@uijaz59/dog-breed-classification-using-pytorch-207cf27c2031
'''

# class Net(nn.Module):
    
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(3, 16, 3)
#         self.conv2 = nn.Conv2d(16, 32, 3)
#         self.conv3 = nn.Conv2d(32, 64, 3)
#         self.conv4 = nn.Conv2d(64, 128, 3)
#         self.conv5 = nn.Conv2d(128, 256, 3)
#         self.fc1 = nn.Linear(256 * 6 * 6, 120)
        
#         self.max_pool = nn.MaxPool2d(2, 2,ceil_mode=True)
#         self.dropout = nn.Dropout(0.2)
#         self.conv_bn1 = nn.BatchNorm2d(224,3)
#         self.conv_bn2 = nn.BatchNorm2d(16)
#         self.conv_bn3 = nn.BatchNorm2d(32)
#         self.conv_bn4 = nn.BatchNorm2d(64)
#         self.conv_bn5 = nn.BatchNorm2d(128)
#         self.conv_bn6 = nn.BatchNorm2d(256)
    
#     def forward(self, x):
        
#         x = F.relu(self.conv1(x))
#         x = self.max_pool(x)
#         x = self.conv_bn2(x)
        
#         x = F.relu(self.conv2(x))
#         x = self.max_pool(x)
#         x = self.conv_bn3(x)
        
#         x = F.relu(self.conv3(x))
#         x = self.max_pool(x)
#         x = self.conv_bn4(x)
        
#         x = F.relu(self.conv4(x))
#         x = self.max_pool(x)
#         x = self.conv_bn5(x)
        
#         x = F.relu(self.conv5(x))
#         x = self.max_pool(x)
#         x = self.conv_bn6(x)
        
#         x = x.view(-1, 256 * 6 * 6)
        
#         x = self.dropout(x)
#         x = self.fc1(x)
#         return x

# net = Net()
# net.to(device)
