# %%
import numpy as np
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
mat = loadmat('../../train_data.mat')
train_data = mat['train_fg_data']
train_labels = mat['train_info'][0, 0]['labels'].reshape(len(train_data), )

# %%
mat1 = loadmat('../../test_data.mat')
test_data = mat1['test_fg_data']
test_labels = mat1['test_info'][0, 0]['labels'].reshape(len(test_data), )
val_data, test_data, val_labels, test_labels = train_test_split(test_data, test_labels, test_size=0.5, random_state=42)
print(test_data.shape, val_data.shape)

# %%
small_data = np.empty((0,5376))
small_labels = np.empty((0,))
for i in range(0, 12000, 100):
    small_data = np.append(small_data, train_data[i:i+15, :], axis=0)
    small_labels = np.append(small_labels, train_labels[i:i+15])
print(small_data.shape, small_labels.shape)
# Out:
# (1800, 5376) (1800,)

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
import time
clf = svm.SVC()
since = time.time()
clf.fit(small_data, small_labels)
time_elapsed = time.time() - since
print('Training complete in {:.0f}m {:.0f}s'.format(
    time_elapsed // 60, time_elapsed % 60))
preds = clf.predict(test_data)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, preds)
np.savetxt('subset_svm_sift_confusion.txt', cm)

meanacc = accuracy_score(test_labels, preds)*100
classacc = 100*(cm.diagonal()/cm.sum(axis=1))
f = open("../../classes.txt", "r")
classmap = {}
for i in range(120):
    classs = f.readline().split(" ")
    classmap[classs[0]] = classacc[i]
    
    
i = 1
with open('subset_svm_sift_accuracies.txt','w') as l:
    for k, v in classmap.items():
        l.write(k + '   {}\n'.format(v))
        i+=1
        
sortedmap = sorted(classmap.items(), key=lambda item: item[1], reverse=True)

for k, v in sortedmap:
    print('Accuracy of %30s : %10d %%' % (k, v))
print('Mean accuracy: %5f %%' % meanacc)
# Out:
# Accuracy of            Irish_water_spaniel :         32 %
# Accuracy of                   bull_mastiff :         26 %
# Accuracy of                Norwich_terrier :         25 %
# Accuracy of                          dhole :         22 %
# Accuracy of             Kerry_blue_terrier :         21 %
# Accuracy of                       Pembroke :         20 %
# Accuracy of                  Saint_Bernard :         20 %
# Accuracy of             Australian_terrier :         19 %
# Accuracy of             miniature_pinscher :         19 %
# Accuracy of                     Weimaraner :         18 %
# Accuracy of                   Irish_setter :         18 %
# Accuracy of                         Saluki :         18 %
# Accuracy of                    EntleBucher :         17 %
# Accuracy of                        Samoyed :         16 %
# Accuracy of                       komondor :         16 %
# Accuracy of                       Pekinese :         16 %
# Accuracy of                    groenendael :         16 %
# Accuracy of           Bouvier_des_Flandres :         16 %
# Accuracy of                         basset :         14 %
# Accuracy of                         kuvasz :         14 %
# Accuracy of     Greater_Swiss_Mountain_dog :         13 %
# Accuracy of    West_Highland_white_terrier :         13 %
# Accuracy of                         vizsla :         12 %
# Accuracy of                       Leonberg :         12 %
# Accuracy of                 Sussex_spaniel :         11 %
# Accuracy of                          Lhasa :         11 %
# Accuracy of          flat_coated_retriever :         11 %
# Accuracy of                     Rottweiler :         11 %
# Accuracy of                 English_setter :         11 %
# Accuracy of                   Afghan_hound :         10 %
# Accuracy of             Scottish_deerhound :         10 %
# Accuracy of               Japanese_spaniel :         10 %
# Accuracy of                      Chihuahua :          9 %
# Accuracy of              Brabancon_griffon :          9 %
# Accuracy of                     bloodhound :          9 %
# Accuracy of               Blenheim_spaniel :          9 %
# Accuracy of               Mexican_hairless :          9 %
# Accuracy of            African_hunting_dog :          8 %
# Accuracy of                 Scotch_terrier :          8 %
# Accuracy of           Bernese_mountain_dog :          8 %
# Accuracy of                   Newfoundland :          8 %
# Accuracy of                     schipperke :          7 %
# Accuracy of               English_foxhound :          7 %
# Accuracy of                giant_schnauzer :          7 %
# Accuracy of                 Dandie_Dinmont :          6 %
# Accuracy of           Old_English_sheepdog :          5 %
# Accuracy of                         briard :          5 %
# Accuracy of                German_shepherd :          5 %
# Accuracy of                   Walker_hound :          5 %
# Accuracy of                  Gordon_setter :          5 %
# Accuracy of                    Maltese_dog :          5 %
# Accuracy of        wire_haired_fox_terrier :          5 %
# Accuracy of                           chow :          5 %
# Accuracy of        black_and_tan_coonhound :          5 %
# Accuracy of                    Boston_bull :          4 %
# Accuracy of              Yorkshire_terrier :          4 %
# Accuracy of                  Irish_terrier :          4 %
# Accuracy of                Irish_wolfhound :          4 %
# Accuracy of                         beagle :          4 %
# Accuracy of                     Pomeranian :          4 %
# Accuracy of                        redbone :          4 %
# Accuracy of                Norfolk_terrier :          4 %
# Accuracy of               golden_retriever :          4 %
# Accuracy of         Welsh_springer_spaniel :          4 %
# Accuracy of                  Border_collie :          4 %
# Accuracy of               Sealyham_terrier :          3 %
# Accuracy of                    Appenzeller :          3 %
# Accuracy of               Brittany_spaniel :          3 %
# Accuracy of                       malamute :          3 %
# Accuracy of                         collie :          3 %
# Accuracy of            miniature_schnauzer :          3 %
# Accuracy of                  silky_terrier :          3 %
# Accuracy of    soft_coated_wheaten_terrier :          3 %
# Accuracy of              Shetland_sheepdog :          3 %
# Accuracy of                       keeshond :          3 %
# Accuracy of                       papillon :          3 %
# Accuracy of                          cairn :          3 %
# Accuracy of                            pug :          3 %
# Accuracy of       Chesapeake_Bay_retriever :          2 %
# Accuracy of            Rhodesian_ridgeback :          2 %
# Accuracy of             Bedlington_terrier :          2 %
# Accuracy of                 Siberian_husky :          2 %
# Accuracy of                        clumber :          2 %
# Accuracy of                       Doberman :          2 %
# Accuracy of                  affenpinscher :          2 %
# Accuracy of                         borzoi :          1 %
# Accuracy of                       Airedale :          1 %
# Accuracy of                          boxer :          1 %
# Accuracy of                Tibetan_mastiff :          1 %
# Accuracy of                Tibetan_terrier :          1 %
# Accuracy of                         kelpie :          1 %
# Accuracy of      Staffordshire_bullterrier :          1 %
# Accuracy of             standard_schnauzer :          1 %
# Accuracy of                 Great_Pyrenees :          1 %
# Accuracy of               English_springer :          1 %
# Accuracy of                 French_bulldog :          1 %
# Accuracy of                   Ibizan_hound :          1 %
# Accuracy of             Norwegian_elkhound :          1 %
# Accuracy of               Lakeland_terrier :          1 %
# Accuracy of                       Shih_Tzu :          0 %
# Accuracy of                    toy_terrier :          0 %
# Accuracy of                       bluetick :          0 %
# Accuracy of              Italian_greyhound :          0 %
# Accuracy of                        whippet :          0 %
# Accuracy of                     otterhound :          0 %
# Accuracy of American_Staffordshire_terrier :          0 %
# Accuracy of                 Border_terrier :          0 %
# Accuracy of         curly_coated_retriever :          0 %
# Accuracy of             Labrador_retriever :          0 %
# Accuracy of    German_short_haired_pointer :          0 %
# Accuracy of                 cocker_spaniel :          0 %
# Accuracy of                       malinois :          0 %
# Accuracy of                     Great_Dane :          0 %
# Accuracy of                     Eskimo_dog :          0 %
# Accuracy of                        basenji :          0 %
# Accuracy of                       Cardigan :          0 %
# Accuracy of                     toy_poodle :          0 %
# Accuracy of               miniature_poodle :          0 %
# Accuracy of                standard_poodle :          0 %
# Accuracy of                          dingo :          0 %
# Mean accuracy: 6.946387 %
